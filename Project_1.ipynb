# %% [markdown]
# <a href="https://colab.research.google.com/github/lmly303/Ml-Learning/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv('Housing.csv', delimiter=";")
print(data.head(n=10))
# Out:
#       price   area  bedrooms  bathrooms  mainroad  guestroom  parking
# 0  13300000   7420         4          2         1          0        2
# 1  12250000   8960         4          4         1          0        3
# 2  12250000   9960         3          2         1          0        2
# 3  12215000   7500         4          2         1          0        3
# 4  11410000   7420         4          1         1          1        2
# 5  10850000   7500         3          3         1          0        2
# 6  10150000   8580         4          3         1          0        2
# 7  10150000  16200         5          3         1          0        0
# 8   9870000   8100         4          1         1          1        2
# 9   9800000   5750         3          2         1          1        1

# %%
x = data[["area", "bedrooms", "bathrooms", "mainroad", "guestroom", "parking"]]
y = data["price"]

x_train, x_test, y_train, y_test  = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x_test)
print(f"Predicted price : {y_predict}")
print(f"Real price : {y_test}")
# Out:
# Predicted price : [5572806.94297024 5830161.38107394 3518870.28964534 4110346.37103245
#  3843758.5890769  4551241.548882   5610597.04706828 6442408.69676217
#  3518771.13495221 2772851.60736475 8641998.96620507 3491698.84263834
#  2688917.64931608 2875385.36965534 3846321.93313417 6335786.62403944
#  2995948.10196331 4665657.56069824 4627207.39983926 4021285.72486925
#  4115473.05914698 5232073.87792883 3418643.53700629 4755639.08454551
#  5840363.54146143 7315031.99276618 3929269.82065072 5586908.17747678
#  6810242.06586823 3252282.5076898  5189325.36675773 3927414.47220596
#  6355911.39465624 4524326.43628072 4398066.18163367 5642102.79413292
#  5271474.77572942 3989212.80449993 2972792.4438314  5223786.78450118
#  5472176.46797598 3413773.18329749 5809654.62861582 4204255.63039056
#  4213536.52916412 4290784.05215001 5701994.1782107  4662437.8207999
#  4546771.25660855 3850236.0755684  6678040.99453587 3551259.2916291
# ...

# %%
sns.pairplot(data, diag_kind="kde")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_predict, color="blue", label="Predicted vs Actual")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="red", linestyle="dashed", label="perfect prediction")  # 45-degree line
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs. Predicted Prices")
plt.legend()
plt.show()

# %% [markdown]
# plt.figure(figsize=(8, 6))
# - Creates a figure with an 8x6 inches size for better visibility.
#
# python
# Copy
# Edit
# plt.scatter(y_test, y_pred, color="blue", label="Predicted vs Actual")
# - Scatter plot of actual vs. predicted prices
# - Each blue dot represents a test data point:
#
# X-axis → Actual house price (y_test)
# Y-axis → Predicted house price (y_pred)
# python
# Copy
# Edit
# plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="red", linestyle="dashed")
# - Plots a red dashed 45-degree line
# - Represents a perfect prediction (y_pred = y_test)
# - If predictions were perfect, all points would lie on this line.
#
# python
# Copy
# Edit
# plt.xlabel("Actual Price")
# plt.ylabel("Predicted Price")
# plt.title("Actual vs. Predicted Prices")
# plt.legend()
# plt.show()
# - Labels and title for better understanding
# - plt.legend() adds a legend for clarity
# - plt.show() displays the plot
